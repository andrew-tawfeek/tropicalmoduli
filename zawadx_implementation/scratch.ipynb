# %%
import networkx as nx
from TropicalGraph import *
from ModuliSpace import *

import numpy as np

# %%
poset, graph_dict = combinatorial_type_poset(1, 2)

# %%
nx.draw_networkx(poset, pos={(lvl, num): (num, lvl) for (lvl, num) in poset.nodes}, node_size=2000)

# %%
graph_dict[(1, 2)].draw()
